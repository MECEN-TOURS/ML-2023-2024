# %%
import requests as rq

# %%
ADRESSE = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

# %%
requete = rq.get(url=ADRESSE)

# %%
dir(requete)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
requete.ok
# Out:
# True

# %% [markdown]
# [page web avec les codes http](https://developer.mozilla.org/fr/docs/Web/HTTP/Status)

# %%
requete.status_code
# Out:
# 200

# %%
requete.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of S&amp;P 500 companies - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disab
# ...

# %%
requete.apparent_encoding
# Out:
# 'utf-8'

# %%
contenu = requete.content.decode("utf-8")
contenu
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of S&amp;P 500 companies - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabl
# ...

# %%
alternative = requete.text
alternative
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of S&amp;P 500 companies - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabl
# ...

# %%
print(contenu[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>List of S&amp;P 500 companies - Wikipedia</title>
# ...

# %%
position_main = contenu.find("""<main id="content" """)
position_main
# Out:
# 21878

# %% [markdown]
# ATTENTION: on voit la page html sans exécution du javascript donc on peut avoir des différences avec l'aperçu dans les outils de développement!

# %%
debut_table = contenu.find("""<table id="constituents" """)
debut_table
# Out:
# -1

# %%
print(contenu[position_main:position_main+1000])
# Out:
# <main id="content" class="mw-body" role="main">
# 				<header class="mw-body-header vector-page-titlebar">
# 					<label
# 						id="vector-toc-collapsed-button"
# 						class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet vector-button-flush-left cdx-button--icon-only"
# 						for="vector-toc-collapsed-checkbox"
# 						role="button"
# 						aria-controls="vector-toc"
# 						tabindex="0"
# 						title="Table of Contents">
# 						<span class="vector-icon mw-ui-icon-wikimedia-listBullet"></span>
# 						<span>Toggle the table of contents</span>
# 					</label>
# 					<nav role="navigation" aria-label="Contents" class="vector-toc-landmark">
#
# <div id="vector-page-titlebar-toc" class="vector-dropdown vector-page-titlebar-toc vector-button-flush-left"  >
# ...

# %%
fin_main = contenu.find("</main>")
print(fin_main)
# Out:
# 676073

# %%
print(contenu[fin_main:fin_main+8])
# Out:
# </main>

# %%
selection01 = contenu[position_main:fin_main + 8]

# %%
print(selection01[:2000])
# Out:
# <main id="content" class="mw-body" role="main">
# 				<header class="mw-body-header vector-page-titlebar">
# 					<label
# 						id="vector-toc-collapsed-button"
# 						class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet vector-button-flush-left cdx-button--icon-only"
# 						for="vector-toc-collapsed-checkbox"
# 						role="button"
# 						aria-controls="vector-toc"
# 						tabindex="0"
# 						title="Table of Contents">
# 						<span class="vector-icon mw-ui-icon-wikimedia-listBullet"></span>
# 						<span>Toggle the table of contents</span>
# 					</label>
# 					<nav role="navigation" aria-label="Contents" class="vector-toc-landmark">
#
# <div id="vector-page-titlebar-toc" class="vector-dropdown vector-page-titlebar-toc vector-button-flush-left"  >
# ...

# %% [markdown]
# # Exercice:
#
# Identifier la balise marquant le début de la table.

# %%
fin_header = selection01.find("</header>")
fin_header
# Out:
# 4545

# %%
print(selection01[fin_header:fin_header+1000])
# Out:
# </header>
# 				<div class="vector-page-toolbar">
# 					<div class="vector-page-toolbar-container">
# 						<div id="left-navigation">
# 							<nav aria-label="Namespaces">
#
# <div id="p-associated-pages" class="vector-menu vector-menu-tabs mw-portlet mw-portlet-associated-pages"  >
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list">
#
# 			<li id="ca-nstab-main" class="selected vector-tab-noicon mw-list-item"><a href="/wiki/List_of_S%26P_500_companies" title="View the content page [c]" accesskey="c"><span>Article</span></a></li><li id="ca-talk" class="vector-tab-noicon mw-list-item"><a href="/wiki/Talk:List_of_S%26P_500_companies" rel="discussion" title="Discuss improvements to the content page [t]" accesskey="t"><span>Talk</span></a></li>
# 		</ul>
#
# 	</div>
# </div>
#
#
# <div id="p-variants" class="vector-dropdown emptyPortlet"  >
# ...

# %%
premiere_entreprise = selection01.find("MMM")
premiere_entreprise
# Out:
# 15464

# %%
print(selection01[premiere_entreprise-1000:premiere_entreprise+1000])
# Out:
# perty="mw:PageProp/toc" />
# <h2><span id="S.26P_500_component_stocks"></span><span class="mw-headline" id="S&amp;P_500_component_stocks">S&amp;P 500 component stocks</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_S%26P_500_companies&amp;action=edit&amp;section=1" title="Edit section: S&amp;P 500 component stocks">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <table class="wikitable sortable" id="constituents">
#
# <tbody><tr>
# <th><a href="/wiki/Ticker_symbol" title="Ticker symbol">Symbol</a>
# </th>
# <th>Security</th>
# <th><a href="/wiki/Global_Industry_Classification_Standard" title="Global Industry Classification Standard">GICS</a> Sector</th>
# <th>GICS Sub-Industry</th>
# <th>Headquarters Location</th>
# <th>Date added</th>
# <th><a href="/wiki/Central_Index_Key" title="Central Index Key">CIK</a></th>
# <th>Founded
# </th></tr>
# <tr>
# ...

# %%
debut_table = selection01.find("<tbody>")
print(debut_table)
# Out:
# 14967

# %%
fin_table = selection01.find("</tbody>", debut_table)
fin_table
# Out:
# 227291

# %%
table = selection01[debut_table + 7: fin_table]
print(table)
# Out:
# <tr>
# <th><a href="/wiki/Ticker_symbol" title="Ticker symbol">Symbol</a>
# </th>
# <th>Security</th>
# <th><a href="/wiki/Global_Industry_Classification_Standard" title="Global Industry Classification Standard">GICS</a> Sector</th>
# <th>GICS Sub-Industry</th>
# <th>Headquarters Location</th>
# <th>Date added</th>
# <th><a href="/wiki/Central_Index_Key" title="Central Index Key">CIK</a></th>
# <th>Founded
# </th></tr>
# <tr>
# <td><a rel="nofollow" class="external text" href="https://www.nyse.com/quote/XNYS:MMM">MMM</a>
# </td>
# <td><a href="/wiki/3M" title="3M">3M</a></td>
# <td>Industrials</td>
# <td>Industrial Conglomerates</td>
# <td><a href="/wiki/Saint_Paul,_Minnesota" title="Saint Paul, Minnesota">Saint Paul, Minnesota</a></td>
# <td>1957-03-04</td>
# <td>0000066740</td>
# <td>1902
# </td></tr>
# <tr>
# <td><a rel="nofollow" class="external text" href="https://www.nyse.com/quote/XNYS:AOS">AOS</a>
# </td>
# ...

# %% [markdown]
# # Exercice
#
# Passer de  `table` à une liste de lignes: `<tr>...</tr>`!

# %%
lignes = list()
debut = table.find("<tr>")
fin = table.find("<tr>", debut + 1)
while fin != -1:
    lignes.append(table[debut:fin].strip())
    debut = fin
    fin = table.find("<tr>", debut + 1)

lignes.append(table[debut:].strip())

# %%
print(lignes[-1])
# Out:
# <tr>
# <td><a rel="nofollow" class="external text" href="https://www.nyse.com/quote/XNYS:ZTS">ZTS</a>
# </td>
# <td><a href="/wiki/Zoetis" title="Zoetis">Zoetis</a></td>
# <td>Health Care</td>
# <td>Pharmaceuticals</td>
# <td><a href="/wiki/Parsippany,_New_Jersey" class="mw-redirect" title="Parsippany, New Jersey">Parsippany, New Jersey</a></td>
# <td>2013-06-21</td>
# <td>0001555280</td>
# <td>1952
# </td></tr>

# %%
len(lignes)
# Out:
# 504

# %% [markdown]
# # Exercice
#
# Obtenir une liste de liste représentant la table.

# %%
titres = lignes[0]
print(titres)
# Out:
# <tr>
# <th><a href="/wiki/Ticker_symbol" title="Ticker symbol">Symbol</a>
# </th>
# <th>Security</th>
# <th><a href="/wiki/Global_Industry_Classification_Standard" title="Global Industry Classification Standard">GICS</a> Sector</th>
# <th>GICS Sub-Industry</th>
# <th>Headquarters Location</th>
# <th>Date added</th>
# <th><a href="/wiki/Central_Index_Key" title="Central Index Key">CIK</a></th>
# <th>Founded
# </th></tr>

# %%
premiere = lignes[1]
print(premiere)
# Out:
# <tr>
# <td><a rel="nofollow" class="external text" href="https://www.nyse.com/quote/XNYS:MMM">MMM</a>
# </td>
# <td><a href="/wiki/3M" title="3M">3M</a></td>
# <td>Industrials</td>
# <td>Industrial Conglomerates</td>
# <td><a href="/wiki/Saint_Paul,_Minnesota" title="Saint Paul, Minnesota">Saint Paul, Minnesota</a></td>
# <td>1957-03-04</td>
# <td>0000066740</td>
# <td>1902
# </td></tr>

# %%
from dataclasses import dataclass

# %%
@dataclass 
class Ligne:
    symbole: str
    nom: str
    lien: str
    domaine: str
    lieu: str
    introduction: str
    code: str
    creation: str

# %%
def extrait(ligne: str) -> Ligne:
    ...

# %%
assert extrait(premiere) == Ligne(
    "MMM",
    "3M",
    "/wiki/3M",
    "Industrials",
    "Industrial Conglomerates",
    "Saint Paul, Minnesota",
    "1957-03-04",
    "0000066740"
    "1902"
)

# %%
import re

# %%
td = re.compile("<td>.*</td>")

# %%
td.match("<td>blablabla123</td>")
# Out:
# <re.Match object; span=(0, 21), match='<td>blablabla123</td>'>

# %%
td.match("prefixe<td>bla bla</td>suffixe")

# %%
td.search("prefixe<td>bla bla</td>suffixe")
# Out:
# <re.Match object; span=(7, 23), match='<td>bla bla</td>'>

# %%
td.search("prefixe<td>bla</td> <td>bla</td>suffixe")
# Out:
# <re.Match object; span=(7, 32), match='<td>bla</td> <td>bla</td>'>

# %%
re?
# Out:
# Type:        module
# String form: <module 're' from '/usr/lib/python3.11/re/__init__.py'>
# File:        /usr/lib/python3.11/re/__init__.py
# Docstring:
# Support for regular expressions (RE).
#
# This module provides regular expression matching operations similar to
# those found in Perl.  It supports both 8-bit and Unicode strings; both
# the pattern and the strings being processed can contain null bytes and
# characters outside the US ASCII range.
#
# Regular expressions can contain both special and ordinary characters.
# Most ordinary characters, like "A", "a", or "0", are the simplest
# regular expressions; they simply match themselves.  You can
# concatenate ordinary characters, so last matches the string 'last'.
#
# The special characters are:
#     "."      Matches any character except a newline.
#     "^"      Matches the start of the string.
#     "$"      Matches the end of the string or just before the newline at
#              the end of the string.
# ...
